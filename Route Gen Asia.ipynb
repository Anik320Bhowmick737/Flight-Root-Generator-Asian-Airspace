# %%
import geopandas
import pandas as pd
from tqdm import tqdm

# %%
Airport = pd.read_csv("Airports.csv")
Runways = pd.read_csv("Runways.csv")
Waypoints = pd.read_csv("Waypoints.csv")
Navaids = pd.read_csv("Navaids.csv")
Airways = pd.read_csv("Airways.csv")

# %%
import networkx as nx
G = nx.DiGraph()
airway_df = pd.read_csv("Airways.csv")
for _, row in airway_df.iterrows():
    source_node = (row['Source'], row['Src_Lat'], row['Src_Long'])
    dest_node = (row['Dest'], row['Dest_Lat'], row['Dest_Long'])
    G.add_node(source_node, lat=row['Src_Lat'], lon=row['Src_Long'])
    G.add_node(dest_node, lat=row['Dest_Lat'], lon=row['Dest_Long'])
    G.add_edge(source_node, dest_node, weight=row['Distance'], airway=row['Airway'])

# %%
from geopy.distance import geodesic

def find_nearest_navaids(airport_icao, nav_aid_df, threshold_nm=20): 
    try:
        airport_lat = Airport[Airport["ICAO"]==airport_icao.upper()]["Latitude"].values[0]
        airport_lon = Airport[Airport["ICAO"]==airport_icao.upper()]["Longitude"].values[0]
        nearest_navaids = []
        for _, row in nav_aid_df.iterrows():
            navaid_lat = row['Latitude']
            navaid_lon = row['Longitude']
            navaid_id = row['Navaid']

            # Calculate distance in kilometers
            distance_km = geodesic((airport_lat, airport_lon), (navaid_lat, navaid_lon)).kilometers
            # Convert distance to nautical miles
            distance_nm = distance_km / 1.852
            if distance_nm <= threshold_nm:
                if len(navaid_id)==3:
                    nearest_navaids.append((navaid_id, distance_nm,navaid_lat,navaid_lon))
        return nearest_navaids
    except: 
        return "Give right input"


def get_Route(src, dest):
    origin_ICAO = src
    dest_ICAO = dest
    try:
        origin_navaids = find_nearest_navaids(origin_ICAO, Navaids)
        dest_navaids = find_nearest_navaids(dest_ICAO, Navaids)
        distance = float('inf')
        f = 0
        for o_nav in origin_navaids:
            for d_nav in dest_navaids:
                source = (o_nav[0], o_nav[2], o_nav[3])
                dest = (d_nav[0], d_nav[2], d_nav[3])
                try:
                    shortest_path = nx.dijkstra_path(G, source=source, target=dest, weight='weight')
                    shortest_path_length = nx.dijkstra_path_length(G, source=source, target=dest, weight='weight')
                    if shortest_path_length < distance:
                        f = 1
                        airways = []
                        route = []
                        distseg = []
                        distance = shortest_path_length
                        for s in shortest_path:
                            route.append(s[0])
                        for u, v in zip(shortest_path[:-1], shortest_path[1:]):
                            airway_name = G[u][v].get('airway', 'Unknown')
                            airways.append(airway_name)
                            distseg.append(G[u][v].get('weight', 'Unknown'))
                except:
                    pass  # Ignore if a route does not exist
        if f == 0:
            return "Route does not exist in the Nav Data"
        return {"Route": route, "Airway": airways, "Distance": distance, "DistanceSegment": distseg, "Coord":[(G.nodes[s]['lat'], G.nodes[s]['lon']) for s in shortest_path]}
    except:
        return "Give correct ICAO"

# %%
def summarize_ATCroute(route):
    wpts = route['Route']
    airways = route['Airway']
    finalRoot = []
    finalRoot.append(wpts[0])
    prev_Away=airways[0]
    for i,a in enumerate(airways):
        if a==prev_Away:
            continue
        else:
            finalRoot.append(airways[i-1])
            finalRoot.append(wpts[i])
            prev_Away = a
    finalRoot.append(airways[-1])
    finalRoot.append(wpts[-1])
    print(" ".join(finalRoot))

# %%
import folium
from IPython.display import display

def plot_route(route_data):
    waypoints = route_data["Route"]
    waypoint_coords = route_data["Coord"]
    airways = route_data['Airway']
    
    avg_lat = sum(coord[0] for coord in waypoint_coords) / len(waypoint_coords)
    avg_lon = sum(coord[1] for coord in waypoint_coords) / len(waypoint_coords)
    m = folium.Map(location=[avg_lat, avg_lon], zoom_start=5, tiles="cartodb positron")

    
    for i, (name, coord) in enumerate(zip(waypoints, waypoint_coords)):
        folium.Marker(
            location=coord,
            popup=name,
            icon=folium.Icon(icon='star', color='green')
        ).add_to(m)
    
    for i in range(len(waypoint_coords) - 1):
        folium.PolyLine(
            locations=[waypoint_coords[i], waypoint_coords[i + 1]],
            color='blue',
            weight=2,
            opacity=0.7,
            popup=f'Airway: {airways[i]}'
        ).add_to(m)

    display(m)

# %% [markdown]
# ## Lets Check the route Kolkata (VECC) to Almaty (UAAA)

# %%
route = get_Route("VECC","UAAA")
print("Waypoints:", route["Route"])
print("\n")
print(f"Total Distance: {route['Distance']:.2f} NM")
print("\n")
print(f"Airways used: {route['Airway']}")
print("\n")
print("ATC route:")
summarize_ATCroute(route)
# Out:
# Waypoints: ['CEA', 'OPESU', 'TEPAL', 'GGC', 'UXUPO', 'GUGIP', 'ASARI', 'SULOM', 'INDEK', 'PUNOP', 'ISDUR', 'RN', 'KASMA', 'TANED', 'SS', 'ONEVI', 'DURKA', 'ATROL', 'GERRY', 'MOTMO', 'FIRUZ', 'VAJEN', 'POMIR', 'ASMAN', 'INLOS', 'OSH', 'IRISU', 'MALEX', 'MEDAS', 'BALVU', 'SOVOP', 'MAMIR', 'LAKEL', 'IZIMA', 'BEDUR', 'DETAK', 'BAKIS', 'ATA']
#
#
# Total Distance: 1870.39 NM
#
#
# Airways used: ['R460', 'R460', 'R460', 'L509', 'L509', 'L509', 'L509', 'L509', 'Z306', 'Z306', 'Z306', 'J149', 'J130', 'J130', 'J130', 'J130', 'J130', 'P500', 'P500', 'P500', 'G500', 'G500', 'B496', 'L142', 'L145', 'L135', 'L135', 'L135', 'L135', 'L135', 'L135', 'P984', 'P984', 'L998', 'L998', 'L998', 'W333']
#
#
# ATC route:
# CEA R460 GGC L509 INDEK Z306 RN J149 KASMA J130 ATROL P500 FIRUZ G500 POMIR B496 ASMAN L142 INLOS L145 OSH L135 MAMIR P984 IZIMA L998 BAKIS W333 ATA

# %%
plot_route(route)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92050094ab45db948a9a325933420d8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92050094ab45db948a9a325933420d8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92050094ab45db948a9a325933420d8a = L.map(
#                 &quot;map_92050094ab45db948a9a325933420d8a&quot;,
#                 {
#                     center: [36.11319315789474, 75.6937587631579],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e88f32cc654815ef061e21834c4b70a0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e88f32cc654815ef061e21834c4b70a0.addTo(map_92050094ab45db948a9a325933420d8a);
#
#
#             var marker_20d2d79d2e1a09f5be823786a2177500 = L.marker(
#                 [22.675917, 88.448111],
#                 {}
#             ).addTo(map_92050094ab45db948a9a325933420d8a);
#
#
#             var icon_afc65981c7fb115449e763925d706923 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_20d2d79d2e1a09f5be823786a2177500.setIcon(icon_afc65981c7fb115449e763925d706923);
#
#
#         var popup_f328cded5e30fad0d078f89e047230b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_069ffb3d81d11c5fddc33d862b4eefad = $(`&lt;div id=&quot;html_069ffb3d81d11c5fddc33d862b4eefad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CEA&lt;/div&gt;`)[0];
#                 popup_f328cded5e30fad0d078f89e047230b4.setContent(html_069ffb3d81d11c5fddc33d862b4eefad);
#
#
#
#         marker_20d2d79d2e1a09f5be823786a2177500.bindPopup(popup_f328cded5e30fad0d078f89e047230b4)
#         ;
#
#
#
#
#             var marker_4424d1c62ecd435ad89842e272f34717 = L.marker(
#                 [23.480278, 87.029167],
#                 {}
#             ).addTo(map_92050094ab45db948a9a325933420d8a);
#
#
#             var icon_dedb01a16a28703ad02c1f961a1fd55b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4424d1c62ecd435ad89842e272f34717.setIcon(icon_dedb01a16a28703ad02c1f961a1fd55b);
#
#
#         var popup_44b14e7b2e3f554a3a602428b24484af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_037d3f60a2cd1dc29eb2042422cf1025 = $(`&lt;div id=&quot;html_037d3f60a2cd1dc29eb2042422cf1025&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;OPESU&lt;/div&gt;`)[0];
#                 popup_44b14e7b2e3f554a3a602428b24484af.setContent(html_037d3f60a2cd1dc29eb2042422cf1025);
#
#
#
#         marker_4424d1c62ecd435ad89842e272f34717.bindPopup(popup_44b14e7b2e3f554a3a602428b24484af)
#         ;
#
#
#
#
#             var marker_898c97c4b9ed19c2f1f78d4d841a5a3a = L.marker(
#                 [23.811667, 86.434167],
#                 {}
#             ).addTo(map_92050094ab45db948a9a325933420d8a);
#
#
#             var icon_bf4957496cce181334bbcec662421b3e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_898c97c4b9ed19c2f1f78d4d841a5a3a.setIcon(icon_bf4957496cce181334bbcec662421b3e);
#
#
#         var popup_9a2b4287756ed752e790bf33822adc79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea7a6f68801a6112b8751b6495a86fa7 = $(`&lt;div id=&quot;html_ea7a6f68801a6112b8751b6495a86fa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;TEPAL&lt;/div&gt;`)[0];
#                 popup_9a2b4287756ed752e790bf33822adc79.setContent(html_ea7a6f68801a6112b8751b6495a86fa7);
#
#
#
#         marker_898c97c4b9ed19c2f1f78d4d841a5a3a.bindPopup(popup_9a2b4287756ed752e790bf33822adc79)
#         ;
#
#
#
#
#             var marker_a8ec928c0b1a9306e88b076b1aa09a5d = L.marker(
#                 [24.742028, 84.943111],
#                 {}
#             ).addTo(map_92050094ab45db948a9a325933420d8a);
#
#
#             var icon_a299243888fa4326ba6d616c5f1e8875 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,

# %% [markdown]
# ## Lets Check the Route Kolkata (VECC) to Mumbai (VABB)

# %%
route = get_Route("VECC","VABB")
print("Waypoints:", route["Route"])
print("\n")
print(f"Total Distance: {route['Distance']:.2f} NM")
print("\n")
print(f"Airways used: {route['Airway']}")
print("\n")
print("ATC route:")
summarize_ATCroute(route)
# Out:
# Waypoints: ['CEA', 'NUDLA', 'JRS', 'OGUNA', 'IKINA', 'OSVAS', 'OMLEG', 'TASEX', 'ASIPI', 'LUXIP', 'OPAKA', 'BBB']
#
#
# Total Distance: 900.62 NM
#
#
# Airways used: ['J46', 'J46', 'W160', 'Z14', 'Z14', 'Q20', 'Q20', 'Q20', 'Q20', 'Q20', 'W18']
#
#
# ATC route:
# CEA J46 JRS W160 OGUNA Z14 OSVAS Q20 OPAKA W18 BBB

# %%
plot_route(route)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18d6ca67af9ce9a7b35319473f785695 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18d6ca67af9ce9a7b35319473f785695&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18d6ca67af9ce9a7b35319473f785695 = L.map(
#                 &quot;map_18d6ca67af9ce9a7b35319473f785695&quot;,
#                 {
#                     center: [20.986893583333334, 80.22519675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d08333328b85fd1b9e5475079973a374 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d08333328b85fd1b9e5475079973a374.addTo(map_18d6ca67af9ce9a7b35319473f785695);
#
#
#             var marker_e442a492631af8b1b17f0d91213cb776 = L.marker(
#                 [22.675917, 88.448111],
#                 {}
#             ).addTo(map_18d6ca67af9ce9a7b35319473f785695);
#
#
#             var icon_2f9582e532c8f00802c42af81ba8382e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e442a492631af8b1b17f0d91213cb776.setIcon(icon_2f9582e532c8f00802c42af81ba8382e);
#
#
#         var popup_fc7c8c125f78444cacfb7f80019215dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54789dfa2415347479784f857f0d5ba2 = $(`&lt;div id=&quot;html_54789dfa2415347479784f857f0d5ba2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CEA&lt;/div&gt;`)[0];
#                 popup_fc7c8c125f78444cacfb7f80019215dd.setContent(html_54789dfa2415347479784f857f0d5ba2);
#
#
#
#         marker_e442a492631af8b1b17f0d91213cb776.bindPopup(popup_fc7c8c125f78444cacfb7f80019215dd)
#         ;
#
#
#
#
#             var marker_6517634e6675ac98460e246612665213 = L.marker(
#                 [22.276389, 86.141667],
#                 {}
#             ).addTo(map_18d6ca67af9ce9a7b35319473f785695);
#
#
#             var icon_6369302c56a29820d4fc5fbf4663d274 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6517634e6675ac98460e246612665213.setIcon(icon_6369302c56a29820d4fc5fbf4663d274);
#
#
#         var popup_2ecd1ddfc66c3aee1b083d5938aa96ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d81a83bf6fdb9f796e0bfb16770ad76 = $(`&lt;div id=&quot;html_7d81a83bf6fdb9f796e0bfb16770ad76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NUDLA&lt;/div&gt;`)[0];
#                 popup_2ecd1ddfc66c3aee1b083d5938aa96ab.setContent(html_7d81a83bf6fdb9f796e0bfb16770ad76);
#
#
#
#         marker_6517634e6675ac98460e246612665213.bindPopup(popup_2ecd1ddfc66c3aee1b083d5938aa96ab)
#         ;
#
#
#
#
#             var marker_dff5e0063c799d782b8e6181cc9a3147 = L.marker(
#                 [21.915917, 84.061778],
#                 {}
#             ).addTo(map_18d6ca67af9ce9a7b35319473f785695);
#
#
#             var icon_f64e80f3c93cb1b79bda19c2f0f66121 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dff5e0063c799d782b8e6181cc9a3147.setIcon(icon_f64e80f3c93cb1b79bda19c2f0f66121);
#
#
#         var popup_f966b552d7d45778b58844611d5687bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63cfe951636fd6b1e0588273d637b833 = $(`&lt;div id=&quot;html_63cfe951636fd6b1e0588273d637b833&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;JRS&lt;/div&gt;`)[0];
#                 popup_f966b552d7d45778b58844611d5687bc.setContent(html_63cfe951636fd6b1e0588273d637b833);
#
#
#
#         marker_dff5e0063c799d782b8e6181cc9a3147.bindPopup(popup_f966b552d7d45778b58844611d5687bc)
#         ;
#
#
#
#
#             var marker_a730b53a85b3c557ebb577da1b903e4a = L.marker(
#                 [21.484444, 82.6725],
#                 {}
#             ).addTo(map_18d6ca67af9ce9a7b35319473f785695);
#
#
#             var icon_1d13a0ee1565582507a1fe5ae71ec123 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;i

# %% [markdown]
# ## Lets Check the Route Mumbai (VABB) to Bangkok (VTBS)

# %%
route = get_Route("VABB","VTBS")
print("Waypoints:", route["Route"])
print("\n")
print(f"Total Distance: {route['Distance']:.2f} NM")
print("\n")
print(f"Airways used: {route['Airway']}")
print("\n")
print("ATC route:")
summarize_ATCroute(route)
# Out:
# Waypoints: ['BBB', 'OPAKA', 'MELAX', 'IBELA', 'BUSBO', 'MEPIP', 'MEPOK', 'VVZ', 'POTAS', 'OLSOR', 'DOGEM', 'URKOK', 'GUSTU', 'MABUR', 'RINDA', 'SADUS', 'DWI', 'TANEK', 'PASTO', 'BKK']
#
#
# Total Distance: 1638.80 NM
#
#
# Airways used: ['G450', 'W218', 'L505', 'L505', 'L301', 'L301', 'L301', 'L301', 'L301', 'L301', 'L301', 'L301', 'L301', 'L301', 'L301', 'L301', 'L301', 'L301', 'L301']
#
#
# ATC route:
# BBB G450 OPAKA W218 MELAX L505 BUSBO L301 BKK

# %%
plot_route(route)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52f10be79115962d2d32bf8f2ba6fc3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52f10be79115962d2d32bf8f2ba6fc3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52f10be79115962d2d32bf8f2ba6fc3e = L.map(
#                 &quot;map_52f10be79115962d2d32bf8f2ba6fc3e&quot;,
#                 {
#                     center: [16.959807250000004, 86.2944837],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d03ec824b0e0915ec0796943f77c5f7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8d03ec824b0e0915ec0796943f77c5f7.addTo(map_52f10be79115962d2d32bf8f2ba6fc3e);
#
#
#             var marker_81b7cb972f365c9fbaefd930c1b97615 = L.marker(
#                 [19.086167, 72.874694],
#                 {}
#             ).addTo(map_52f10be79115962d2d32bf8f2ba6fc3e);
#
#
#             var icon_adac391edb2e8559474797fa04851fee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_81b7cb972f365c9fbaefd930c1b97615.setIcon(icon_adac391edb2e8559474797fa04851fee);
#
#
#         var popup_9663d741cde5da6c26486444ede37046 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59fd3bc6c42643797677db9f8f386d04 = $(`&lt;div id=&quot;html_59fd3bc6c42643797677db9f8f386d04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BBB&lt;/div&gt;`)[0];
#                 popup_9663d741cde5da6c26486444ede37046.setContent(html_59fd3bc6c42643797677db9f8f386d04);
#
#
#
#         marker_81b7cb972f365c9fbaefd930c1b97615.bindPopup(popup_9663d741cde5da6c26486444ede37046)
#         ;
#
#
#
#
#             var marker_f341a858c462bcf6997e734b40ed35a6 = L.marker(
#                 [19.605833, 74.549444],
#                 {}
#             ).addTo(map_52f10be79115962d2d32bf8f2ba6fc3e);
#
#
#             var icon_89d889f200c7ee2cf49c6babe63710e5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f341a858c462bcf6997e734b40ed35a6.setIcon(icon_89d889f200c7ee2cf49c6babe63710e5);
#
#
#         var popup_50fd7c48f3cf10667a6b4ac4c12641b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9409d4f93b138d75e29167da717bfd46 = $(`&lt;div id=&quot;html_9409d4f93b138d75e29167da717bfd46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;OPAKA&lt;/div&gt;`)[0];
#                 popup_50fd7c48f3cf10667a6b4ac4c12641b5.setContent(html_9409d4f93b138d75e29167da717bfd46);
#
#
#
#         marker_f341a858c462bcf6997e734b40ed35a6.bindPopup(popup_50fd7c48f3cf10667a6b4ac4c12641b5)
#         ;
#
#
#
#
#             var marker_3abd1c9ed9efc7a0a19005fe82aaa8a1 = L.marker(
#                 [19.498611, 75.6325],
#                 {}
#             ).addTo(map_52f10be79115962d2d32bf8f2ba6fc3e);
#
#
#             var icon_834b46c8843b65dfe8851eaafc6f9759 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3abd1c9ed9efc7a0a19005fe82aaa8a1.setIcon(icon_834b46c8843b65dfe8851eaafc6f9759);
#
#
#         var popup_df01565864c185496ed2e0afe0dc606a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2af972b2b5f73c51da81b028fbfbb4e = $(`&lt;div id=&quot;html_a2af972b2b5f73c51da81b028fbfbb4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MELAX&lt;/div&gt;`)[0];
#                 popup_df01565864c185496ed2e0afe0dc606a.setContent(html_a2af972b2b5f73c51da81b028fbfbb4e);
#
#
#
#         marker_3abd1c9ed9efc7a0a19005fe82aaa8a1.bindPopup(popup_df01565864c185496ed2e0afe0dc606a)
#         ;
#
#
#
#
#             var marker_d5f886ff066dc05c2b09efac1150e835 = L.marker(
#                 [19.375833, 76.832222],
#                 {}
#             ).addTo(map_52f10be79115962d2d32bf8f2ba6fc3e);
#
#
#             var icon_e3153fcbc1ddebaf01351a7bf26243b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;

# %% [markdown]
# ## Lets Check the Route Chennai (VOMM) to Delhi (VIDP)

# %%
route = get_Route("VOMM","VIDP")
print("Waypoints:", route["Route"])
print("\n")
print(f"Total Distance: {route['Distance']:.2f} NM")
print("\n")
print(f"Airways used: {route['Airway']}")
print("\n")
print("ATC route:")
summarize_ATCroute(route)
# Out:
# Waypoints: ['MMV', 'KAMGU', 'KIKUR', 'ANDAV', 'ALBED', 'LAROB', 'SUDEL', 'TASEX', 'RENAG', 'BPL', 'PUKES', 'BUKLO', 'BAVOX', 'SURGO', 'SAPLO', 'DPN']
#
#
# Total Distance: 956.19 NM
#
#
# Airways used: ['W20', 'Q24', 'Q24', 'Q24', 'Q24', 'Q24', 'Q24', 'Q24', 'Q24', 'W20', 'W20', 'W20', 'W20', 'W20', 'W20']
#
#
# ATC route:
# MMV W20 KAMGU Q24 BPL W20 DPN

# %%
plot_route(route)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd3db7e6ad9f70a68a12e66bb8793e9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd3db7e6ad9f70a68a12e66bb8793e9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd3db7e6ad9f70a68a12e66bb8793e9e = L.map(
#                 &quot;map_fd3db7e6ad9f70a68a12e66bb8793e9e&quot;,
#                 {
#                     center: [21.4824496875, 78.06539412500001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1efb716e024560af1ea378c022e8eda = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f1efb716e024560af1ea378c022e8eda.addTo(map_fd3db7e6ad9f70a68a12e66bb8793e9e);
#
#
#             var marker_ca5bdbadc2e8b6b7ee7d230a8f2c3925 = L.marker(
#                 [12.987639, 80.155028],
#                 {}
#             ).addTo(map_fd3db7e6ad9f70a68a12e66bb8793e9e);
#
#
#             var icon_b3f41371f2fdc081da8e4e1f304c4228 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca5bdbadc2e8b6b7ee7d230a8f2c3925.setIcon(icon_b3f41371f2fdc081da8e4e1f304c4228);
#
#
#         var popup_302250be65d1cceb2998c3b91b12c149 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2134f29f04bcd0dffe14d3ae9c27cec1 = $(`&lt;div id=&quot;html_2134f29f04bcd0dffe14d3ae9c27cec1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MMV&lt;/div&gt;`)[0];
#                 popup_302250be65d1cceb2998c3b91b12c149.setContent(html_2134f29f04bcd0dffe14d3ae9c27cec1);
#
#
#
#         marker_ca5bdbadc2e8b6b7ee7d230a8f2c3925.bindPopup(popup_302250be65d1cceb2998c3b91b12c149)
#         ;
#
#
#
#
#             var marker_cc11a96e2edde3ef8c9b717f9c31beae = L.marker(
#                 [14.975278, 79.42],
#                 {}
#             ).addTo(map_fd3db7e6ad9f70a68a12e66bb8793e9e);
#
#
#             var icon_0e9546dd2eb1acd87b2c87c66e0342f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cc11a96e2edde3ef8c9b717f9c31beae.setIcon(icon_0e9546dd2eb1acd87b2c87c66e0342f7);
#
#
#         var popup_0129c30bc0685d7870a14d5237807610 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30eb3cf58304b993221f0dc2312f6f06 = $(`&lt;div id=&quot;html_30eb3cf58304b993221f0dc2312f6f06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAMGU&lt;/div&gt;`)[0];
#                 popup_0129c30bc0685d7870a14d5237807610.setContent(html_30eb3cf58304b993221f0dc2312f6f06);
#
#
#
#         marker_cc11a96e2edde3ef8c9b717f9c31beae.bindPopup(popup_0129c30bc0685d7870a14d5237807610)
#         ;
#
#
#
#
#             var marker_f133d1e194d9db85e344cc2f11c2993d = L.marker(
#                 [15.981944, 79.175556],
#                 {}
#             ).addTo(map_fd3db7e6ad9f70a68a12e66bb8793e9e);
#
#
#             var icon_33e191e8c8de198b69a8bb69750a96fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f133d1e194d9db85e344cc2f11c2993d.setIcon(icon_33e191e8c8de198b69a8bb69750a96fd);
#
#
#         var popup_54a65b6284c1b655c43144f9e8f591b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_232e13aa6a0a803474f10559c1f1438d = $(`&lt;div id=&quot;html_232e13aa6a0a803474f10559c1f1438d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KIKUR&lt;/div&gt;`)[0];
#                 popup_54a65b6284c1b655c43144f9e8f591b8.setContent(html_232e13aa6a0a803474f10559c1f1438d);
#
#
#
#         marker_f133d1e194d9db85e344cc2f11c2993d.bindPopup(popup_54a65b6284c1b655c43144f9e8f591b8)
#         ;
#
#
#
#
#             var marker_0c26db5f98945b2a11466f732d479c4f = L.marker(
#                 [17.471667, 78.813611],
#                 {}
#             ).addTo(map_fd3db7e6ad9f70a68a12e66bb8793e9e);
#
#
#             var icon_d48ec9cb6e7f9233df5a6f1b0885aed8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;
